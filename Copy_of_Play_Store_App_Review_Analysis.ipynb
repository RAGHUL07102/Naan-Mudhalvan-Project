# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv('Training_Data_Google_Play_reviews_6000.csv')

# %%
# Display basic information about the dataset
print("Number of rows and columns:", data.shape)
print("\nColumns present in the dataset:")
print(data.columns)
# Out:
# Number of rows and columns: (6000, 13)
#
# Columns present in the dataset:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion', 'userLang', 'app_id'],
#       dtype='object')

# %%
# Display the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(data.head())
# Out:
# First few rows of the dataset:
#                                reviewId           userName  \
# 0  495266a4-f451-48c3-a844-fb3c07560d55     Foysal Hossain
# 1  947fcd83-7a28-403d-b03b-d0bc20f52e0e          S K VERMA
# 2  65856211-67ba-4560-84dd-a0055775ed90      Amanuel Abara
# 3  cd5ba250-3a26-43b4-a378-77d18f73a503  Vagarangas X Aopi
# 4  e8e886b4-d6c6-416b-b0a1-be90320c4024       Shafin islam
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                       content  score  thumbsUpCount reviewCreatedVersion  \
# 0  Gett van for no reason 😂😂😂      1              0                  NaN
# 1       better' than WhatsApp      4              0                  NaN
# ...

# %%
# Summary statistics
print("\nSummary statistics:")
print(data.describe())
# Out:
# Summary statistics:
#              score  thumbsUpCount
# count  6000.000000    6000.000000
# mean      3.297167       6.993667
# std       1.778122     232.865931
# min       1.000000       0.000000
# 25%       1.000000       0.000000
# 50%       4.000000       0.000000
# 75%       5.000000       0.000000
# max       5.000000   14491.000000

# %%
# Check for missing values
print("\nMissing values:")
print(data.isnull().sum())
# Out:
# Missing values:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    1604
# at                         0
# replyContent            5809
# repliedAt               5809
# appVersion              1604
# userLang                   0
# app_id                     0
# dtype: int64

# %%
# Analyze ratings
print("\nAverage rating:", data['score'].mean())
print("Maximum rating:", data['score'].max())
print("Minimum rating:", data['score'].min())
# Out:
# Average rating: 3.2971666666666666
# Maximum rating: 5
# Minimum rating: 1

# %%
# Analyze thumbs up count
print("\nAverage thumbs up count:", data['thumbsUpCount'].mean())
print("Maximum thumbs up count:", data['thumbsUpCount'].max())
print("Minimum thumbs up count:", data['thumbsUpCount'].min())
# Out:
# Average thumbs up count: 6.993666666666667
# Maximum thumbs up count: 14491
# Minimum thumbs up count: 0

# %%
# Analyze review creation version
print("\nNumber of unique review creation versions:", data['reviewCreatedVersion'].nunique())
# Out:
# Number of unique review creation versions: 307

# %%
# Analyze app versions
print("\nNumber of unique app versions:", data['appVersion'].nunique())
# Out:
# Number of unique app versions: 307

# %%
# Analyze user languages
print("\nNumber of unique user languages:", data['userLang'].nunique())
# Out:
# Number of unique user languages: 5

# %%
# Visualization
# Distribution of ratings
plt.figure(figsize=(8, 6))
sns.histplot(data['score'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Distribution of thumbs up count
plt.figure(figsize=(8, 6))
sns.histplot(data['thumbsUpCount'], bins=20, kde=True, color='salmon')
plt.title('Distribution of Thumbs Up Count')
plt.xlabel('Thumbs Up Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Barplot of top 10 categories by review count
top_categories = data['content'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_categories.index, y=top_categories.values, palette='viridis')
plt.title('Top 10 Categories by Review Count')
plt.xlabel('Category')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-14-b1052993e6e2>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.index, y=top_categories.values, palette='viridis')
